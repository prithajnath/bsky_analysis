# %%
import pandas as pd
import numpy as np
from datetime import date
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
import seaborn as sns

import re
import duckdb

# %%
user_labels_df = pd.read_csv("kmeans_cluster_labels.csv")
users_df = pd.read_csv("sample_users.csv")

# %%
user_labels_df.shape[0], users_df.shape[0]
# Out:
# (23335, 98421)

# %%
with duckdb.connect("file.db") as conn:
    first_post_sql = """
    with ranked_posts as (
        select
            author_did,
            body,
            created_at,
            row_number() over (partition by author_did order by created_at) as r
        from
            all_posts
    ) select * from ranked_posts where r = 1;

    """
    first_post_df = conn.execute(first_post_sql).df()

# %%
first_post_df
# Out:
#                              author_did  \
# 0      did:plc:kmaleldosvavjfjjo7wl6e6a
# 1      did:plc:le7k5zwsli5545o5habpizir
# 2      did:plc:ljbhqcwg5hougnhecdmmkmeb
# 3      did:plc:lndyvhazyfzvxf374avdchx6
# 4      did:plc:lv26i2oswc5r6a22q2mh4dpi
# ...                                 ...
# 23330  did:plc:hzd5xbub4sreswusx4dfr3ih
# 23331  did:plc:ifgltyxgrdfqv4hwwrg4bwt4
# 23332  did:plc:it3dgoo6w6xo53ndjiku56fd
# 23333  did:plc:jdfkui5fng3yg6f5qsamalkz
# 23334  did:plc:jl5mqn5eis5rhwu7yobkhh23
#
#                                                     body  \
# 0      Mr Krabs from SpongeBob has been arrested in B...
# 1         me when they say to put my figures at the end
# 2      If you're also new here and wondering how long...
# 3      Anyone, any entity, anywhere in the world can ...
# 4      Absolutely thrilled to share my postdoc work i...
# ...                                                  ...
# 23330                                                🚲🌸🍁
# 23331  Three little kids are stomping around the bloc...
# 23332  Let's try this BlueSky !\n\nA dedicated accoun...
# 23333  EcoEvo folks, this is a fun game! Figure out e...
# 23334  Dav Pilkey Gives Away 50,000 Books To Challeng...
#
#                             created_at  r
# 0     2023-09-07 11:20:12.715000-04:00  1
# 1            2023-04-19 07:17:27-04:00  1
# 2     2023-09-20 05:53:29.665000-04:00  1
# 3     2024-11-25 17:28:34.480000-05:00  1
# 4     2023-10-14 11:58:40.573000-04:00  1
# ...                                ... ..
# 23330 2024-11-06 08:34:44.579000-05:00  1
# 23331        2018-09-01 09:31:15-04:00  1
# 23332 2023-10-16 09:16:42.475000-04:00  1
# 23333 2023-08-26 07:18:11.899000-04:00  1
# 23334        2024-03-12 10:27:36-04:00  1
#
# [23335 rows x 4 columns]

# %%
users_df = users_df.rename(columns={"did":"author_did"})
users_df
# Out:
#                              author_did                       handle  \
# 0      did:plc:ooehugjick2vkzwlr64lephm         haleaziz.bsky.social
# 1      did:plc:qy3kg6jvtlhenv5ojqurynwh      joshuacroke.bsky.social
# 2      did:plc:ibqwicj6ersmvw36yldikozx   inspiringtimmy.bsky.social
# 3      did:plc:czowt24mxhkxcvxqffdg2t6u  quetzallicortez.bsky.social
# 4      did:plc:f4ultoamz3y2m4drcjvhoecu   wilmonstouches.bsky.social
# ...                                 ...                          ...
# 98416  did:plc:iwguck4nqz7ky3snlfop2gdj         annshiro.bsky.social
# 98417  did:plc:a4ndyz2v2sw3l4zyogvfmrxs      ruchikapose.bsky.social
# 98418  did:plc:b25v5fuvq4q374w5jxvfgdwl               anggia.bsky.to
# 98419  did:plc:s3ha2cfuskferixapyqztime      itsourqueen.bsky.social
# 98420  did:plc:mbf2svsfn54ezlsg4poxknca               jongin.bsky.to
#
#                                                      bio  \
# 0      I cover DHS and immigration policy for the New...
# 1      Founder of 🏳️‍🌈 queerforcities.com / 🌈loveyour...
# 2      Best known for watching the Queen's Gambit fro...
# 3                                                    NaN
# 4      same name but not rosh‘s ex | #OMAR : ”oh, tha...
# ...                                                  ...
# 98416  == illustrator｜中/日/Eng 🆗 | 📫annshiro@163.com｜\...
# 98417  女の子ポーズ&衣装資料ならおまかせ！ \n絵描きによる絵描き目線の作画資料\n🎀中の人るちか...
# 98418                                                NaN
# 98419                                                NaN
# 98420  (1994) The emanate lissomeness of a dignitary ...
#
#                     created_at
# 0      2024-11-18 15:39:52.581
# 1      2024-11-15 11:45:12.223
# 2      2024-11-06 08:11:15.881
# 3      2024-11-24 18:10:16.146
# 4      2024-11-15 17:01:25.026
# ...                        ...
# 98416  2024-03-03 05:16:06.510
# 98417  2024-03-22 12:05:20.239
# 98418  2024-06-09 22:34:26.421
# 98419  2024-06-08 05:35:12.293
# 98420  2024-06-16 11:17:19.590
#
# [98421 rows x 4 columns]

# %%
HAS_MENTIONS_REGEX = r".*(@\w+)"

with open("url_regex.txt", "r") as f:
    URL_REGEX = f.read()

# Has mentions in first post Boolean
def has_mentions_in_bio(bio):
    return True if re.match(HAS_MENTIONS_REGEX, bio) else False

# Has mentions in first post Boolean
def has_mentions_in_first_post(first_post):
    return True if re.match(HAS_MENTIONS_REGEX, first_post) else False

# Has URL in bio
def has_url_in_bio(bio):
    return True if re.match(URL_REGEX, bio) else False
# Has URL in first post
def has_url_in_first_post(first_post):
    return True if re.match(URL_REGEX, first_post) else False

# %%
transformations = [has_mentions_in_bio, has_mentions_in_first_post, has_url_in_bio, has_url_in_first_post]

df = pd.merge(first_post_df, users_df, how="left", on="author_did")

for transformation in transformations:
    name = transformation.__name__
    if name.endswith("bio"):
        df[name] = df["bio"].apply(lambda x:transformation(x) if isinstance(x, str) else "")
    if name.endswith("post"):
        df[name] = df["body"].apply(lambda x:transformation(x) if isinstance(x, str) else "")

# %%
final_df = df[["author_did"] + [i.__name__ for i in transformations]]
final_df
# Out:
#                              author_did has_mentions_in_bio  \
# 0      did:plc:kmaleldosvavjfjjo7wl6e6a               False
# 1      did:plc:le7k5zwsli5545o5habpizir               False
# 2      did:plc:ljbhqcwg5hougnhecdmmkmeb               False
# 3      did:plc:lndyvhazyfzvxf374avdchx6               False
# 4      did:plc:lv26i2oswc5r6a22q2mh4dpi               False
# ...                                 ...                 ...
# 23330  did:plc:hzd5xbub4sreswusx4dfr3ih               False
# 23331  did:plc:ifgltyxgrdfqv4hwwrg4bwt4               False
# 23332  did:plc:it3dgoo6w6xo53ndjiku56fd               False
# 23333  did:plc:jdfkui5fng3yg6f5qsamalkz               False
# 23334  did:plc:jl5mqn5eis5rhwu7yobkhh23               False
#
#        has_mentions_in_first_post has_url_in_bio  has_url_in_first_post
# 0                           False          False                  False
# 1                           False          False                  False
# 2                           False          False                  False
# 3                           False          False                  False
# 4                           False          False                  False
# ...                           ...            ...                    ...
# 23330                       False          False                  False
# 23331                       False          False                  False
# 23332                       False          False                  False
# 23333                       False          False                  False
# 23334                       False          False                  False
#
# [23335 rows x 5 columns]

# %%
final_df[final_df["has_url_in_bio"] == True]
# Out:
#                              author_did has_mentions_in_bio  \
# 58     did:plc:5niusquxbyjcu7xladonnxym               False
# 220    did:plc:lghkt7kri3ouxsggv3jscxkp               False
# 227    did:plc:opbenuyiz7vnbopkomegs6ac               False
# 366    did:plc:vbmszr2gffpr254j33mezwig               False
# 404    did:plc:qjvqocu6gx4vmcqsjiu7px3z               False
# ...                                 ...                 ...
# 22378  did:plc:2bnru3l4lbnxwbpdpywsmtnq               False
# 22524  did:plc:gdal6xjdupuuugf7u4c6zxyr               False
# 22647  did:plc:jg2b5vutlufg3mm7uwyzcbee               False
# 22719  did:plc:d6dkjstsyw3zqthf2qtqkjp2                True
# 23105  did:plc:22dn52nqxqzl5deex74u67db               False
#
#        has_mentions_in_first_post has_url_in_bio  has_url_in_first_post
# 58                          False           True                  False
# 220                         False           True                  False
# 227                         False           True                  False
# 366                         False           True                  False
# 404                         False           True                  False
# ...                           ...            ...                    ...
# 22378                       False           True                  False
# 22524                       False           True                  False
# 22647                       False           True                  False
# 22719                       False           True                  False
# 23105                       False           True                  False
#
# [184 rows x 5 columns]

# %%
final_df.to_csv("prithaj_features.csv", index=False)
